# %% [markdown]
# # Example-how hann window works

# %%
import matplotlib.pyplot as plt
from numpy.fft import fft, fftshift
import numpy as np
window = np.hanning(128)
plt.plot(window)
plt.title("Hann window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
# Out:
# Text(0.5,0,'Sample')

# %%
plt.figure()
A = fft(window, 2048) / 25.5
mag = np.abs(fftshift(A))
freq = np.linspace(-0.5, 0.5, len(A))
response = 20 * np.log10(mag)
response = np.clip(response, -100, 100)
plt.plot(freq, response)
plt.title("Frequency response of the Hann window")
plt.ylabel("Magnitude [dB]")
plt.xlabel("Normalized frequency [cycles per sample]")
plt.axis('tight')
# Out:
# C:\Users\EMO\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log10
#   """
# (-0.55, 0.55, -105.39623354485802, 13.320904442018431)
